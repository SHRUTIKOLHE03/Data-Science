# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df.head()
# Out:
#    Roll No       Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        1  Student_1        100         62       73.0       92.0          96
# 1        2  Student_2         72         97       82.0        NaN          78
# 2        3  Student_3        100         88       71.0       99.0         -94
# 3        4  Student_4         72         99        NaN       84.0          86
# 4        5  Student_5         97         70       84.0       70.0          86

# %%
df.tail()
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96

# %%
df.info
# Out:
# <bound method DataFrame.info of       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]>

# %%
df.describe()
# Out:
#            Roll No    Subject 1    Subject 2   Subject 3    Subject 4  \
# count  1001.000000  1001.000000  1001.000000  1001.00000  1001.000000
# mean    500.000999    79.233766    80.064935    79.81019    80.464535
# std     289.106384    12.085913    11.904318    11.80686    12.059560
# min       1.000000    60.000000    60.000000     0.00000     0.000000
# 25%     250.000000    69.000000    70.000000    70.00000    71.000000
# 50%     500.000000    79.000000    80.000000    80.00000    81.000000
# 75%     750.000000    90.000000    91.000000    90.00000    91.000000
# max    1000.000000   100.000000   100.000000   100.00000   100.000000
#
#         Attendance
# count  1001.000000
# mean     85.416583
# std      10.277319
# min     -94.000000
# 25%      79.000000
# 50%      86.000000
# 75%      93.000000
# max     100.000000

# %%
pd.notnull(df)
# Out:
#       Roll No  Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        True  True       True       True       True       True        True
# 1        True  True       True       True       True       True        True
# 2        True  True       True       True       True       True        True
# 3        True  True       True       True       True       True        True
# 4        True  True       True       True       True       True        True
# ...       ...   ...        ...        ...        ...        ...         ...
# 996      True  True       True       True       True       True        True
# 997      True  True       True       True       True       True        True
# 998      True  True       True       True       True       True        True
# 999      True  True       True       True       True       True        True
# 1000     True  True       True       True       True       True        True
#
# [1001 rows x 7 columns]

# %%
df.fillna(0, inplace =True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        0.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        0.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df.head()
# Out:
#    Roll No       Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        1  Student_1        100         62       73.0       92.0          96
# 1        2  Student_2         72         97       82.0        0.0          78
# 2        3  Student_3        100         88       71.0       99.0         -94
# 3        4  Student_4         72         99        0.0       84.0          86
# 4        5  Student_5         97         70       84.0       70.0          86

# %%
df.isnull().sum()
# Out:
# Roll No       0
# Name          0
# Subject 1     0
# Subject 2     0
# Subject 3     0
# Subject 4     0
# Attendance    0
# dtype: int64

# %%
df=pd.read_csv('A1.csv')
df.fillna(method='pad')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df=pd.read_csv('A1.csv')
df.fillna(method='bfill')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df = pd.read_csv('A1.csv')
df.interpolate(method='linear')
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       95.5
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       77.5       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df = pd.read_csv('A1.csv')
nc=['Subject 1', 'Subject 2', 'Subject 3', 'Subject 4', 'Attendance']
for col in nc:
    df[col].fillna(df[col].mean(), inplace=True )

df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df=pd.read_csv('A1.csv')
df.replace(to_replace=np.nan, value= 85)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# 4             86
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [1001 rows x 7 columns]

# %%
df.dropna(how='any', inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# 6             83
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [999 rows x 7 columns]

# %%
df.drop_duplicates()
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# 6             83
# ...          ...
# 996           98
# 997           83
# 998           90
# 999           79
# 1000          96
#
# [999 rows x 7 columns]

# %%
x = df[['Subject 1', 'Subject 2', 'Subject 3', 'Subject 4', 'Attendance']]
print(df[x<0])
# Out:
#       Roll No Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 2         NaN  NaN        NaN        NaN        NaN        NaN       -94.0
# 4         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 5         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 6         NaN  NaN        NaN        NaN        NaN        NaN         NaN
# ...       ...  ...        ...        ...        ...        ...         ...
# 996       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 997       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 998       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 999       NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 1000      NaN  NaN        NaN        NaN        NaN        NaN         NaN
#
# [999 rows x 7 columns]

# %%
x=x.clip(lower=0)
x
# Out:
#       Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0           100         62       73.0       92.0          96
# 2           100         88       71.0       99.0           0
# 4            97         70       84.0       70.0          86
# 5            98         76       89.0       92.0          82
# 6            61         64       97.0       98.0          83
# ...         ...        ...        ...        ...         ...
# 996          88         68       84.0       66.0          98
# 997          61         96       62.0       84.0          83
# 998          72         76       90.0       72.0          90
# 999          68         87      100.0       76.0          79
# 1000        100         62       73.0       92.0          96
#
# [999 rows x 5 columns]

# %%
for col in nc:
    sns.boxplot(x=df[col])
    plt.title("Box PLot")
    plt.show()

# %%
for col in nc:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lb = Q1 - 1.5*IQR
    ub = Q3 + 1.5*IQR
    df[col] = np.where((df[col]<lb) | (df[col]>ub), df[col].median(), df[col])

print(df)
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1      100.0       62.0       73.0       92.0
# 2           3     Student_3      100.0       88.0       71.0       99.0
# 4           5     Student_5       97.0       70.0       84.0       70.0
# 5           6     Student_6       98.0       76.0       89.0       92.0
# 6           7     Student_7       61.0       64.0       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997       88.0       68.0       84.0       66.0
# 997       998   Student_998       61.0       96.0       62.0       84.0
# 998       999   Student_999       72.0       76.0       90.0       72.0
# 999      1000  Student_1000       68.0       87.0      100.0       76.0
# 1000        1     Student_1      100.0       62.0       73.0       92.0
#
#       Attendance
# 0           96.0
# 2           86.0
# 4           86.0
# 5           82.0
# 6           83.0
# ...          ...
# 996         98.0
# 997         83.0
# 998         90.0
# 999         79.0
# 1000        96.0
#
# [999 rows x 7 columns]
